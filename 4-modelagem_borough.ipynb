# %% [markdown]
# # 4 - Modelagem com Machine Learning
#
# P1: É possível predizer a taxa de poluição emitida no ar nos próximos anos?\
# P2: A estação do ano influencia a quantidade de poluentes no ar de alguma forma?
#
# 1 - tentar fazer previsões utilziando modelos lineares para ambos perguntas 1 e 2
#
# 2 - tentar verificar se eles conseguem prever com corretude anos posteriores ao treinamento do modelo.
#
# 3 - Aplicar modelos mais complexos para as mesmas coisas que a regressão linear tentou verificar
#
# 4 - verificar se as regressões mais complexas conseguem prever melhor que a regressão linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression, r_regression, RFECV
from sklearn.impute import SimpleImputer
from sklearn.model_selection import TimeSeriesSplit 

import duckdb
import pandas as pd
import numpy as np
import os 

PM25_ID = 365
NO2_ID = 375
O3_ID = 386

SPLIT_YEAR=2020

BOROS = ["Bronx", "Brooklyn", "Manhattan", "Queens", "Staten Island"]

OUT_FOLDER = "./out"

# %%
def calc_KBest(features: list, target_col: str, df: pd.DataFrame):
    X = df[features]
    y = df[target_col]

    imputer = SimpleImputer(strategy='mean')
    X_imp = imputer.fit_transform(X)

    selector = SelectKBest(f_regression, k=3).fit(X_imp, y)

    feat_scores = pd.Series(selector.scores_, index=features)
    feat_scores.sort_values(ascending=False, inplace=True)

    return feat_scores

def calc_RFECV(features: list, target_col: str, df: pd.DataFrame, features_qtd: int = 3, model  = LinearRegression()):
    df = df.dropna().copy()

    n_samples = min(len(df) - 1, 3)

    X = df[features]
    y = df[target_col]

    imputer = SimpleImputer(strategy='mean')
    X_imp = imputer.fit_transform(X)

    selector = RFECV(estimator=model, cv=TimeSeriesSplit(n_samples), scoring='r2', min_features_to_select=features_qtd)
    selector.fit(X_imp, y)

    feat_scores = pd.Series(selector.ranking_, index=features)
    feat_scores.sort_values(ascending=False, inplace=True)

    return feat_scores

def linear_regression(data: pd.DataFrame, features: list, target_col: str, split_year: int, pollutant_id: int):
    df_filtered = data[data['IndicatorID'] == pollutant_id].dropna().copy()

    X_train = df_filtered[df_filtered['Year'] < split_year][features]
    y_train = df_filtered[df_filtered['Year'] < split_year][target_col]
    X_test = df_filtered[df_filtered['Year'] >= split_year][features]
    y_test = df_filtered[df_filtered['Year'] >= split_year][target_col]
    
    # Padronização (Scaling)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    
    # Treinamento do Modelo
    model = LinearRegression()
    model.fit(X_train_scaled, y_train)
    
    # Predição e Avaliação
    y_pred = model.predict(X_test_scaled)
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    # Coeficientes (Betas Padronizados)
    betas = pd.Series(model.coef_, index=features).sort_values(ascending=False)
    
    # Output
    pollutant_name = df_filtered['Name'].iloc[0] # Pega o nome do poluente
    print("-------------------------------------------------")
    print(f"## Resultados RL | {pollutant_name} ({df_filtered['GeoPlaceName'].iloc[0]})")
    print(f"Período Treino: {df_filtered['Year'].min()} - {split_year-1} | Teste: {split_year} - {df_filtered['Year'].max()}")
    print(f"R-quadrado (R²): {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print("\n## Coeficientes:")
    print(betas)
    print("-------------------------------------------------")

def rf_regression(data: pd.DataFrame, features: list, target_col: str, split_year: int, pollutant_id: int):
    df_filtered = data[data['IndicatorID'] == pollutant_id].copy()

    # Separação Treino/Teste por ano
    X_train = df_filtered[df_filtered['Year'] < split_year][features]
    y_train = df_filtered[df_filtered['Year'] < split_year][target_col]
    X_test = df_filtered[df_filtered['Year'] >= split_year][features]
    y_test = df_filtered[df_filtered['Year'] >= split_year][target_col]
    
    # Treinamento do Modelo
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    
    # Predição e Avaliação
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    # Importância das Features
    importances = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
    
    # Output
    pollutant_name = df_filtered['Name'].iloc[0] # Pega o nome do poluente
    print("-------------------------------------------------")
    print(f"## Resultados RF | {pollutant_name} (({df_filtered['GeoPlaceName'].iloc[0]}))")
    print(f"Período Treino: {df_filtered['Year'].min()} - {split_year-1} | Teste: {split_year} - {df_filtered['Year'].max()}")
    print(f"R-quadrado (R²): {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print("\n## Importância das Features:")
    print(importances)
    print("-------------------------------------------------")

def gradient_boosting_regression(data: pd.DataFrame, features: list, target_col: str, split_year: int, pollutant_id: int):
    df_filtered = data[data['IndicatorID'] == pollutant_id].dropna().copy()

    # Separação Treino/Teste por ano
    X_train = df_filtered[df_filtered['Year'] < split_year][features]
    y_train = df_filtered[df_filtered['Year'] < split_year][target_col]
    X_test = df_filtered[df_filtered['Year'] >= split_year][features]
    y_test = df_filtered[df_filtered['Year'] >= split_year][target_col]
    
    # Treinamento do Modelo
    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)
    
    # Predição e Avaliação
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))

    # Importância das Features
    importances = pd.Series(model.feature_importances_, index=features).sort_values(ascending=False)
    
    # Output
    pollutant_name = df_filtered['Name'].iloc[0] # Pega o nome do poluente
    print("-------------------------------------------------")
    print(f"## Resultados GB | {pollutant_name} (({df_filtered['GeoPlaceName'].iloc[0]}))")
    print(f"Período Treino: {df_filtered['Year'].min()} - {split_year-1} | Teste: {split_year} - {df_filtered['Year'].max()}")
    print(f"R-quadrado (R²): {r2:.3f}")
    print(f"RMSE: {rmse:.3f}")
    print("\n## Importância das Features:")
    print(importances)
    print("-------------------------------------------------")

# %% [markdown]
# # Feature selection de dados Borough

# %%
P1_seasonal_borough = pd.read_parquet(os.path.join(OUT_FOLDER, "seasonal_borough_air_quality.parquet"))

sql_query = f"""
with base as(
    select 
        indicatorid,
        name,
        year,
		geoplacename,
        AVG(datavalue) AS DataValue
    from P1_seasonal_borough
    group by indicatorid, name, year, geoplacename
)
select
    indicatorid,
    name,
    year,
		geoplacename,
    DataValue as Current,
    lag(DataValue, 1) over (
            partition by indicatorid, geoplacename
            order by year
        ) as Lag1,
    lag(DataValue, 2) over (
            partition by indicatorid, geoplacename
            order by year
        ) as Lag2,
    lag(DataValue, 3) over (
            partition by indicatorid, geoplacename
            order by year
        ) as Lag3
from base
order by year, name;
"""

df_query = duckdb.query(sql_query).to_df()

TARGET_COL = 'Current'
FEATURES = ['Lag1','Lag2','Lag3','Year']

df_PM25 = df_query[df_query['IndicatorID'] == PM25_ID]
df_NO2 = df_query[df_query['IndicatorID'] == NO2_ID]
df_O3 = df_query[df_query['IndicatorID'] == O3_ID]

# %%
for df in [df_PM25, df_NO2, df_O3]:
    for boro in BOROS:
        df_filtered_boro = df_query[df_query['GeoPlaceName'] == boro] 
        train_df = df_filtered_boro[df_filtered_boro['Year'] < SPLIT_YEAR]
        
        res = calc_RFECV(
            features=FEATURES,
            target_col=TARGET_COL,
            df=train_df,
            features_qtd=1,
            model=LinearRegression()
        )

        linear_regression(
            data=df_filtered_boro, 
            features=res.index.tolist()[:1],
            target_col=TARGET_COL,
            split_year=SPLIT_YEAR,
            pollutant_id=df_filtered_boro['IndicatorID'].iloc[0] 
        )
# Out:
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -3.095
# RMSE: 0.668
#
# ## Coeficientes:
# Lag1    0.761907
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.994
# RMSE: 0.824
#
# ## Coeficientes:
# Lag1    0.644306
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.588
# RMSE: 0.508
#
# ## Coeficientes:
# Year   -1.024397
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.945
# RMSE: 0.707
#
# ## Coeficientes:
# Lag1    0.596979
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.797
# RMSE: 0.786
#
# ## Coeficientes:
# Lag1    0.727295
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -3.095
# RMSE: 0.668
#
# ## Coeficientes:
# Lag1    0.761907
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.994
# RMSE: 0.824
#
# ## Coeficientes:
# Lag1    0.644306
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.588
# RMSE: 0.508
#
# ## Coeficientes:
# Year   -1.024397
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.945
# RMSE: 0.707
#
# ## Coeficientes:
# Lag1    0.596979
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.797
# RMSE: 0.786
#
# ## Coeficientes:
# Lag1    0.727295
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -3.095
# RMSE: 0.668
#
# ## Coeficientes:
# Lag1    0.761907
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.994
# RMSE: 0.824
#
# ## Coeficientes:
# Lag1    0.644306
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.588
# RMSE: 0.508
#
# ## Coeficientes:
# Year   -1.024397
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.945
# RMSE: 0.707
#
# ## Coeficientes:
# Lag1    0.596979
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.797
# RMSE: 0.786
#
# ## Coeficientes:
# Lag1    0.727295
# dtype: float64
# -------------------------------------------------

# %%
for df in [df_PM25, df_NO2, df_O3]:
    for boro in BOROS:
        df_boro = df[df['GeoPlaceName'] == boro]

        for model in [LinearRegression(), RandomForestRegressor(), GradientBoostingRegressor()]:
            train_df = df_boro[df_boro['Year'] < SPLIT_YEAR] #evitar data leakage

            res = calc_RFECV(
                features=FEATURES,
                target_col=TARGET_COL,
                df=train_df,
                model=model
            )

            model_name = model.__class__.__name__

            if model_name == "LinearRegression":
                linear_regression(
                    data=df_boro,
                    features=res.index.tolist()[:3],
                    target_col=TARGET_COL,
                    split_year=SPLIT_YEAR,
                    pollutant_id=df_boro['IndicatorID'].iloc[0]
                )

            if model_name == "RandomForestRegressor":
                rf_regression(
                    data=df_boro,
                    features=res.index.tolist()[:3],
                    target_col=TARGET_COL,
                    split_year=SPLIT_YEAR,
                    pollutant_id=df_boro['IndicatorID'].iloc[0]
                )

            if model_name == "GradientBoostingRegressor":
                gradient_boosting_regression(
                    data=df_boro,
                    features=res.index.tolist()[:3],
                    target_col=TARGET_COL,
                    split_year=SPLIT_YEAR,
                    pollutant_id=df_boro['IndicatorID'].iloc[0]
            )
# Out:
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -4.126
# RMSE: 0.748
#
# ## Coeficientes:
# Lag3    0.578526
# Lag2    0.432390
# Lag1    0.071685
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Fine particles (PM 2.5) ((Bronx))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -6.227
# RMSE: 0.888
#
# ## Importância das Features:
# Lag1    0.473642
# Lag2    0.301787
# Lag3    0.224571
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Fine particles (PM 2.5) ((Bronx))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.020
# RMSE: 0.469
#
# ## Importância das Features:
# Lag1    0.920625
# Lag3    0.075160
# Lag2    0.004214
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.275
# RMSE: 0.466
#
# ## Coeficientes:
# Lag3    0.553181
# Lag2    0.269340
# Lag1    0.069795
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Fine particles (PM 2.5) ((Brooklyn))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -3.442
# RMSE: 0.869
#
# ## Importância das Features:
# Lag3    0.608336
# Lag2    0.252005
# Lag1    0.139659
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Fine particles (PM 2.5) ((Brooklyn))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.286
# RMSE: 0.624
#
# ## Importância das Features:
# Lag1    0.933127
# Lag3    0.058523
# Lag2    0.008350
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.344
# RMSE: 0.578
#
# ## Coeficientes:
# Lag1    0.468353
# Lag2    0.297638
# Lag3    0.296023
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Fine particles (PM 2.5) ((Manhattan))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -19.105
# RMSE: 1.417
#
# ## Importância das Features:
# Lag3    0.541702
# Lag2    0.248236
# Lag1    0.210062
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Fine particles (PM 2.5) ((Manhattan))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -15.289
# RMSE: 1.276
#
# ## Importância das Features:
# Lag1    0.882582
# Lag3    0.115305
# Lag2    0.002113
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.196
# RMSE: 0.389
#
# ## Coeficientes:
# Lag3    0.457660
# Lag2    0.362161
# Lag1    0.047810
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Fine particles (PM 2.5) ((Queens))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -6.579
# RMSE: 0.980
#
# ## Importância das Features:
# Lag3    0.368843
# Lag2    0.317401
# Lag1    0.313756
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Fine particles (PM 2.5) ((Queens))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -7.112
# RMSE: 1.014
#
# ## Importância das Features:
# Lag1    0.904375
# Lag3    0.073786
# Lag2    0.021840
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Fine particles (PM 2.5) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.392
# RMSE: 0.554
#
# ## Coeficientes:
# Lag3    0.577875
# Lag2    0.201826
# Lag1    0.185967
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Fine particles (PM 2.5) ((Staten Island))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.895
# RMSE: 0.799
#
# ## Importância das Features:
# Lag3    0.562859
# Lag2    0.226619
# Lag1    0.210522
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Fine particles (PM 2.5) ((Staten Island))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.604
# RMSE: 0.595
#
# ## Importância das Features:
# Lag1    0.899785
# Lag3    0.074863
# Lag2    0.025352
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Nitrogen dioxide (NO2) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -11.990
# RMSE: 2.614
#
# ## Coeficientes:
# Lag3    1.370841
# Lag2   -0.268252
# Lag1   -0.522155
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Nitrogen dioxide (NO2) ((Bronx))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.952
# RMSE: 1.442
#
# ## Importância das Features:
# Lag3    0.500273
# Lag2    0.342283
# Lag1    0.157443
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Nitrogen dioxide (NO2) ((Bronx))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.592
# RMSE: 1.375
#
# ## Importância das Features:
# Lag3    0.875784
# Lag1    0.123842
# Lag2    0.000375
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Nitrogen dioxide (NO2) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.692
# RMSE: 1.027
#
# ## Coeficientes:
# Lag3    0.969135
# Lag2    0.097378
# Lag1   -0.155995
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Nitrogen dioxide (NO2) ((Brooklyn))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.413
# RMSE: 1.226
#
# ## Importância das Features:
# Lag3    0.404737
# Lag2    0.404003
# Lag1    0.191260
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Nitrogen dioxide (NO2) ((Brooklyn))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.415
# RMSE: 0.939
#
# ## Importância das Features:
# Lag1    0.908674
# Lag3    0.062570
# Lag2    0.028756
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Nitrogen dioxide (NO2) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.811
# RMSE: 2.512
#
# ## Coeficientes:
# Lag3    1.450003
# Lag2    0.339760
# Lag1   -0.031927
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Nitrogen dioxide (NO2) ((Manhattan))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -7.736
# RMSE: 3.803
#
# ## Importância das Features:
# Lag1    0.372157
# Lag3    0.351178
# Lag2    0.276665
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Nitrogen dioxide (NO2) ((Manhattan))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -4.690
# RMSE: 3.070
#
# ## Importância das Features:
# Lag1    0.504333
# Lag3    0.486493
# Lag2    0.009174
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Nitrogen dioxide (NO2) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -22.157
# RMSE: 2.061
#
# ## Coeficientes:
# Lag3    1.121683
# Lag2   -0.193103
# Lag1   -0.222075
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Nitrogen dioxide (NO2) ((Queens))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -14.097
# RMSE: 1.664
#
# ## Importância das Features:
# Lag3    0.519080
# Lag2    0.294703
# Lag1    0.186217
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Nitrogen dioxide (NO2) ((Queens))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -6.293
# RMSE: 1.157
#
# ## Importância das Features:
# Lag3    0.890535
# Lag1    0.082461
# Lag2    0.027004
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Nitrogen dioxide (NO2) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.011
# RMSE: 0.656
#
# ## Coeficientes:
# Lag3    0.626125
# Lag2    0.043116
# Lag1   -0.140865
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Nitrogen dioxide (NO2) ((Staten Island))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -1.672
# RMSE: 0.756
#
# ## Importância das Features:
# Lag3    0.437816
# Lag2    0.370839
# Lag1    0.191345
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Nitrogen dioxide (NO2) ((Staten Island))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.551
# RMSE: 0.576
#
# ## Importância das Features:
# Lag3    0.585459
# Lag2    0.359876
# Lag1    0.054666
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Ozone (O3) (Bronx)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.248
# RMSE: 1.444
#
# ## Coeficientes:
# Lag2    0.477723
# Lag1   -0.033295
# Lag3   -1.046401
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Ozone (O3) ((Bronx))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.808
# RMSE: 1.738
#
# ## Importância das Features:
# Lag3    0.430441
# Lag1    0.353248
# Lag2    0.216312
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Ozone (O3) ((Bronx))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -2.586
# RMSE: 2.448
#
# ## Importância das Features:
# Lag3    0.581098
# Lag2    0.405569
# Lag1    0.013333
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Ozone (O3) (Brooklyn)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.042
# RMSE: 3.010
#
# ## Coeficientes:
# Lag1   -0.228011
# Lag2   -0.535895
# Lag3   -1.085377
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Ozone (O3) ((Brooklyn))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.085
# RMSE: 3.071
#
# ## Importância das Features:
# Lag3    0.465754
# Lag1    0.346025
# Lag2    0.188221
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Ozone (O3) ((Brooklyn))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.136
# RMSE: 3.142
#
# ## Importância das Features:
# Lag3    0.912396
# Lag1    0.052064
# Lag2    0.035540
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Ozone (O3) (Manhattan)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -20.826
# RMSE: 4.598
#
# ## Coeficientes:
# Lag2   -0.316418
# Lag1   -0.684632
# Year   -0.781671
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Ozone (O3) ((Manhattan))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -3.783
# RMSE: 2.152
#
# ## Importância das Features:
# Lag3    0.464523
# Lag1    0.405785
# Lag2    0.129692
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Ozone (O3) ((Manhattan))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -5.403
# RMSE: 2.490
#
# ## Importância das Features:
# Lag3    0.842394
# Lag1    0.114588
# Lag2    0.043018
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Ozone (O3) (Queens)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.056
# RMSE: 2.731
#
# ## Coeficientes:
# Lag2   -0.180679
# Lag1   -0.211774
# Lag3   -0.917769
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Ozone (O3) ((Queens))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.249
# RMSE: 2.970
#
# ## Importância das Features:
# Lag3    0.547763
# Lag1    0.331795
# Lag2    0.120443
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Ozone (O3) ((Queens))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.401
# RMSE: 3.146
#
# ## Importância das Features:
# Lag3    0.940999
# Lag1    0.048990
# Lag2    0.010010
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RL | Ozone (O3) (Staten Island)
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.058
# RMSE: 3.136
#
# ## Coeficientes:
# Lag1    0.034476
# Lag2   -0.165657
# Lag3   -0.985092
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados RF | Ozone (O3) ((Staten Island))
# Período Treino: 2009 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.106
# RMSE: 3.205
#
# ## Importância das Features:
# Lag3    0.479277
# Lag2    0.311926
# Lag1    0.208797
# dtype: float64
# -------------------------------------------------
# -------------------------------------------------
# ## Resultados GB | Ozone (O3) ((Staten Island))
# Período Treino: 2012 - 2019 | Teste: 2020 - 2023
# R-quadrado (R²): -0.805
# RMSE: 4.095
#
# ## Importância das Features:
# Lag3    0.850221
# Lag2    0.078225
# Lag1    0.071554
# dtype: float64
# -------------------------------------------------
